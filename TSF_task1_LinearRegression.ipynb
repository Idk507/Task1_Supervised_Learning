# %% [markdown]
# ## **Linear Regression with Python Scikit Learn**
# In this section we will see how the Python Scikit-Learn library for machine learning can be used to implement regression functions. We will start with simple linear regression involving two variables.
#
# ### **Simple Linear Regression**
# In this regression task we will predict the percentage of marks that a student is expected to score based upon the number of hours they studied. This is a simple linear regression task as it involves just two variables.

# %%
# Importing all libraries required in this notebook
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
# Reading data from remote link
url = "student_scores - student_scores.csv"
s_data = pd.read_csv(url)
print("Data imported successfully")

s_data.head(10)
# Out:
# Data imported successfully
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %% [markdown]
# Let's plot our data points on 2-D graph to eyeball our dataset and see if we can manually find any relationship between the data. We can create the plot with the following script:

# %%
# Plotting the distribution of scores
s_data.plot(x='Hours', y='Scores', style='o')  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %% [markdown]
# **From the graph above, we can clearly see that there is a positive linear relation between the number of hours studied and percentage of score.**

# %% [markdown]
# ### **Preparing the data**
#
# The next step is to divide the data into "attributes" (inputs) and "labels" (outputs).

# %%
X = s_data.iloc[:, :-1].values  
y = s_data.iloc[:, 1].values

# %% [markdown]
# Now that we have our attributes and labels, the next step is to split this data into training and test sets. We'll do this by using Scikit-Learn's built-in train_test_split() method:

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                            test_size=0.2, random_state=0)

# %% [markdown]
# ### **Training the Algorithm**
# We have split our data into training and testing sets, and now is finally the time to train our algorithm.

# %%
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 

print("Training complete.")
# Out:
# Training complete.

# %%
# Plotting the regression line
line = regressor.coef_*X+regressor.intercept_

# Plotting for the test data
plt.scatter(X, y)
plt.plot(X, line);
plt.show()

# %% [markdown]
# ### **Making Predictions**
# Now that we have trained our algorithm, it's time to make some predictions.

# %%
print(X_test) # Testing data - In Hours
y_pred = regressor.predict(X_test) # Predicting the scores
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
# Comparing Actual vs Predicted
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
# You can also test with your own data
hours = 9.25
own_pred = regressor.predict(hours)
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = 9.25
# Predicted Score = 93.69173248737539

# %% [markdown]
# ### **Evaluating the model**
#
# The final step is to evaluate the performance of algorithm. This step is particularly important to compare how well different algorithms perform on a particular dataset. For simplicity here, we have chosen the mean square error. There are many such metrics.

# %%
from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.183859899002982

# %% [markdown]
# Linear Regression using TensorFlow

# %%
import tensorflow as tf

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(1,input_shape= [1]))
model.compile(loss = 'mean_squared_error',optimizer= tf.keras.optimizers.Adam(0.01))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X,y,epochs = 50)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1387.2512
# Epoch 2/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1383.3203
# Epoch 3/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1379.3984
# Epoch 4/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1375.4850
# Epoch 5/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1371.5806
# Epoch 6/50
# 1/1 [==============================] - 0s 0s/step - loss: 1367.6851
# Epoch 7/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1363.7981
# Epoch 8/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1359.9200
# Epoch 9/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1356.0508
# Epoch 10/50
# 1/1 [==============================] - 0s 0s/step - loss: 1352.1899
# Epoch 11/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1348.3381
# Epoch 12/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1344.4950
# Epoch 13/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1340.6605
# Epoch 14/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1336.8347
# Epoch 15/50
# 1/1 [==============================] - 0s 0s/step - loss: 1333.0175
# Epoch 16/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1329.2089
# Epoch 17/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1325.4092
# Epoch 18/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1321.6182
# Epoch 19/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1317.8354
# Epoch 20/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1314.0614
# Epoch 21/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1310.2961
# Epoch 22/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1306.5394
# Epoch 23/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1302.7911
# Epoch 24/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1299.0514
# Epoch 25/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1295.3203
# Epoch 26/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1291.5978
# Epoch 27/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1287.8837
# Epoch 28/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1284.1781
# Epoch 29/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1280.4811
# Epoch 30/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1276.7925
# Epoch 31/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1273.1123
# Epoch 32/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1269.4407
# Epoch 33/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1265.7775
# Epoch 34/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1262.1227
# Epoch 35/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1258.4763
# Epoch 36/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1254.8383
# Epoch 37/50
# 1/1 [==============================] - 0s 0s/step - loss: 1251.2087
# Epoch 38/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1247.5875
# Epoch 39/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1243.9747
# Epoch 40/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1240.3702
# Epoch 41/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1236.7742
# Epoch 42/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1233.1862
# Epoch 43/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1229.6068
# Epoch 44/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1226.0355
# Epoch 45/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1222.4727
# Epoch 46/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1218.9180
# Epoch 47/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1215.3716
# Epoch 48/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1211.8335
# Epoch 49/50
# 1/1 [==============================] - 0s 0s/step - loss: 1208.3036
# Epoch 50/50
# 1/1 [==============================] - 0s 0s/step - loss: 1204.7819

# %%
model.predict(X)
# Out:
# 1/1 [==============================] - 0s 120ms/step
# array([[12.007415],
#        [21.220188],
#        [14.487778],
#        [33.26766 ],
#        [15.55079 ],
#        [ 8.464041],
#        [35.74802 ],
#        [22.637539],
#        [32.558987],
#        [12.71609 ],
#        [30.43296 ],
#        [24.054886],
#        [19.094162],
#        [14.842114],
#        [ 7.046692],
#        [34.68501 ],
#        [12.007415],
#        [ 9.881391],
#        [24.763561],
#        [29.36995 ],
#        [12.71609 ],
#        [20.157177],
#        [16.6138  ],
#        [27.598263],
#        [30.7873  ]], dtype=float32)
